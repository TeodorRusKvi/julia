# %%
############################## IMPORT ###################################

using Random
using Distributions


############################## STRUCTS ##################################

# Event Struct to store arrivals and departures
struct Event
    time::Float64  # Time of event (arrival or departure)
    is_arrival::Bool  # True if it's an arrival, False for a departure
    server_id::Int
    event_id::Int
    customer_id::Int
end

mutable struct Server
    id::Int 
    in_service::Int # Number of customers it keeps in service
    in_queue::Int # Number of customers it keeps in queue
    max_capacity::Int # Number of customers it can service at once
    max_queue_length::Int # Number of customers it can hold in the queue
end

# Define a mutable struct for QueueState with state logging and tracking different types of departures
mutable struct QueueState
    servers::Vector{Server}  # List of servers
    last_event_time::Float64  # Last event time
    total_queue_time::Float64 # Total time in the queue
    total_time::Float64  # Total simulation time / Total time in the system
    lost_customers::Int  # Number of customers who left due to full queues
    state_times::Dict{Int, Float64}  # Time spent in each state
    avg_queue_lengths::Vector{Float64} # A list of average queue lengths
end


########################### STATE INITIALIZING #############################

# Initialize servers
function init_servers(num_servers::Int, max_server_capacity::Int, max_queue_length::Int)
    return [Server(
        i, 
        0, 
        0, 
        max_server_capacity, 
        max_queue_length
        ) for i in 1:num_servers]
end

# Initialize queue state
function init_queue_state(num_servers::Int, max_server_capacity::Int, max_queue_length::Int)
    servers = init_servers(num_servers, max_server_capacity, max_queue_length)
    return QueueState(
        servers, 
        0.0, 
        0.0, 
        0.0, 
        0, 
        Dict{Int, Float64}(), 
        zeros(Float64, num_servers))
end


################################ LOGGING ######################################

# Log the state before processing an event
function log_event_before(event::Event, current_time::Float64, queue_state::QueueState)
    println("<br />########### Event: $(event.event_id) ###########")
    println("Customer ID: $(event.customer_id)")
    println("Current time: $current_time")
    if event.is_arrival
        println("Customer $(event.customer_id) is arriving at server $(event.server_id).")
    else
        println("Customer $(event.customer_id) is leaving from server $(event.server_id).")
    end
    println("System state before event:")
    for server in queue_state.servers
        println("  Server $(server.id): In Service = $(server.in_service), Queue Length = $(server.in_queue)")
    end
    println("Total lost customers so far: $(queue_state.lost_customers)")
end


# Log the state after processing an event
function log_event_after(current_time::Float64, queue_state::QueueState, average_queue_length::Float64)
    println("System state after event:")
    println("Current time: $current_time")
    for server in queue_state.servers
        println("  Server $(server.id): In Service = $(server.in_service), Queue Length = $(server.in_queue)")
    end
    println("Total lost customers: $(queue_state.lost_customers)")
    println("Total waiting time in queue: $(queue_state.total_queue_time)")
    println("Total simulation time: $(queue_state.total_time)")
    println("Average queue length: $average_queue_length")

    # Sort and print state times
    sorted_state_times = sort(collect(queue_state.state_times), by = x -> x[1])
    println("Sorted state times (State -> Time Spent):")
    for (state, time_spent) in sorted_state_times
        println("  State $state: $time_spent")
    end
    println("")
end


###################### UPDATE STATE TIMES ########################

function update_state_times!(queue_state::QueueState, time_in_queue::Float64)
    # Update state times
    current_state = sum(server.in_queue for server in queue_state.servers)
    if haskey(queue_state.state_times, current_state)
        queue_state.state_times[current_state] += time_in_queue
    else
        queue_state.state_times[current_state] = time_in_queue
    end
end


######################### CALCULATE STEADY STATE ##########################

function calculate_steady_state(avg_queue_lengths::Vector{Float64}, current_avg_queue_length::Float64, current_time::Float64; threshold::Float64=0.1)
    if length(avg_queue_lengths) < 5
        return (Float64[], nothing)
    end

    # looking at the recent 5 queue lengths
    recent_avg_lengths = avg_queue_lengths[end-4:end]
    deviations = [abs(current_avg_queue_length - avg) / avg for avg in recent_avg_lengths]

    # Finding the steady state by comparing the last 5 deviations with the treshold
    steady_state_time = if all(dev -> dev < threshold, deviations)
        current_time
    else
        nothing
    end

    return (deviations, steady_state_time)
end

function log_deviations(deviations::Vector{Float64})
    println("<br />Deviations:")
    for deviation in enumerate(deviations)
        #if i <= length(event_ids)
        println("Deviation: $deviation")
    end
end


################ EVENT HANDLING #################################

# Handle an arrival event
function handle_arrival!(queue_state::QueueState, server::Server)
    if server.in_service < server.max_capacity
        server.in_service += 1
    elseif server.in_queue < server.max_queue_length
        server.in_queue += 1
    else
        # Check if any other server has space in the queue
        placed_in_queue = false
        for other_server in queue_state.servers
            if other_server.id != server.id && other_server.in_queue < other_server.max_queue_length
                other_server.in_queue += 1
                placed_in_queue = true
                break
            end
        end
        # If no space was found in any queue, increment lost customers
        # The lost customer is never assigned to a server
        if !placed_in_queue
            queue_state.lost_customers += 1
        end
    end
end


# Handle a departure event
function handle_departure!(server::Server)
    if server.in_queue > 0 #If there are someone in the queue
        server.in_queue -= 1 # subtracts one from the queue
    else #If there are no one in the queue
        server.in_service -= 1 #We subtract one from the service
    end
end


############################### EVENT GENERATING ################################

# Generate arrival and departure events
function generate_events(arrival_times, service_times, num_servers)
    events = Vector{Event}()
    event_id_counter = 1
    last_departure_times = zeros(Float64, num_servers)
    max_departure_time = 0.0

    for i in 1:length(arrival_times)
        arrival_time = arrival_times[i]
        service_time = service_times[i]

        # Assign the server with the earliest predicted availability
        server_id = argmin(last_departure_times)
        
        # Customer ID is equal to the iteration through the for the loop, each iteration is one customer 
        customer_id = i

        # Creates an arrival event by setting isarrival to true
        push!(events, Event(arrival_time, true, server_id, event_id_counter, customer_id))
        event_id_counter += 1

        departure_time = max(arrival_time, last_departure_times[server_id]) + service_time
        
        # Update the list of departure times 
        last_departure_times[server_id] = departure_time

        # Update the max departure time
        max_departure_time = max(max_departure_time, departure_time)

        # Creates an departure event by setting isarrival to false
        push!(events, Event(departure_time, false, server_id, event_id_counter, customer_id))
        event_id_counter += 1
    end

    sort!(events, by = e -> e.time)
    #sorted_events = [Event(event.time, event.is_arrival, event.server_id, index, event.customer_id) for (index, event) in enumerate(events)]
    
    return events, max_departure_time
end


############################## EVENT PROCESSING ###############################

# Function to process an event in a queuing system
function process_event!(event, queue_state, time_limit, verbose)
    # Extract the current time from the event
    current_time = event.time

    # Check if the current time exceeds the time limit
    if current_time > time_limit
        println("Time limit reached: $time_limit")
        return false  # Stop processing further events
    end

    # Get the server associated with the event
    server = queue_state.servers[event.server_id]

    # Calculate the time elapsed since the last event
    time_in_queue = current_time - queue_state.last_event_time

    # Update the total time spent in queues for all servers
    queue_state.total_queue_time += sum(server.in_queue for server in queue_state.servers) * time_in_queue

    # Update the state of servers with the elapsed time
    update_state_times!(queue_state, time_in_queue)

    # Optionally log the event details before processing
    if verbose
        log_event_before(event, current_time, queue_state)
    end

    # Handle the event based on whether it's an arrival or departure
    if event.is_arrival
        handle_arrival!(queue_state, server)  # Process an arrival event
    else
        handle_departure!(server)  # Process a departure event
    end

    # Update the last event time to the current event's time
    queue_state.last_event_time = current_time

    # Update the total system time
    queue_state.total_time = current_time

    # Calculate the current average queue length
    current_avg_queue_length = queue_state.total_queue_time / queue_state.total_time

    # Store the current average queue length in the queue state
    push!(queue_state.avg_queue_lengths, current_avg_queue_length)

    # Check for steady-state conditions and calculate deviations
    deviations, steady_state_time = calculate_steady_state(queue_state.avg_queue_lengths, current_avg_queue_length, current_time)

    # Optionally log any deviations identified
    if verbose
        log_deviations(deviations)
    end

    # If steady-state is reached, log the time and stop processing
    if steady_state_time !== nothing
        println("Steady state reached at time: $steady_state_time")
        return false  # Indicate no further processing is needed
    end

    # Optionally log the event details after processing
    if verbose
        log_event_after(current_time, queue_state, current_avg_queue_length)
    end

    return true  # Indicate successful processing of the event
end
# Out:
# process_event! (generic function with 1 method)

# %%
###################### GENERATOR FOR DISTRIBUTIONS #########################

# Function to generate arrival times and service times
function generate_distributions(
    num_customers::Int,
    arrival_rate::Float64,
    service_mean::Float64,
)
    # Calculate the mean inter-arrival time
    interarrival_mean = 1.0 / arrival_rate

    # Generate inter-arrival times using an exponential distribution
    interarrival_times = rand(Exponential(interarrival_mean), num_customers)

    # Convert inter-arrival times to cumulative arrival times
    #arrival_times = interarrival_times
    arrival_times = cumsum(interarrival_times)

    # Generate random service times using an exponential distribution
    service_times = rand(Exponential(service_mean), num_customers)

    return arrival_times, service_times
end
# Out:
# generate_distributions (generic function with 1 method)

# %%
########################## MAIN SIMULATION #################################

# Main simulation function
function simulate_queue(arrival_rate::Float64, service_mean::Float64, num_customers::Int, num_servers::Int, max_server_capacity::Int, max_queue_length::Int, time_limit::Float64, verbose::Bool=false)
    queue_state = init_queue_state(num_servers, max_server_capacity, max_queue_length)
    arrival_times, service_times = generate_distributions(
    num_customers, 
    arrival_rate, 
    service_mean,
    )
    events, total_planned_time = generate_events(
    arrival_times, 
    service_times, 
    num_servers,
    )
    
    for event in events
        if !process_event!(event, queue_state, time_limit, verbose)
            break
        end
    end
    println("Total planned simulation time: ", total_planned_time)
end
# Out:
# simulate_queue (generic function with 2 methods)

# %%
########################### PARAMETERS #############################

# Parameters for generating distributions
arrival_rate = 50.0 / 60.0 # customers per minute (50 per hour converted)
CloakFloat_service_mean = 1.25 # service time in minutes
CloakSloth_service_mean = 0.8333 # service time in minutes
num_customers = 50

# Parameters for simulating the queue
CloakFloat_num_servers = 3
CloakSloth_num_servers = 2
max_server_capacity = 1
max_queue_length = 10000 # very large number
time_limit = 100.0 # very large number
# Out:
# 100.0

# %%
########################### SIMULATION: CloakFloat #############################

simulate_queue(
arrival_rate, 
CloakFloat_service_mean, 
num_customers,
CloakFloat_num_servers, 
max_server_capacity, 
max_queue_length,
time_limit,
true
)
# Out:
# <br />########### Event: 1 ###########
# Customer ID: 1
# Current time: 0.5103456272665138
# Customer 1 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# System state after event:
# Current time: 0.5103456272665138
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 0.5103456272665138
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 0.5103456272665138
#
# <br />########### Event: 3 ###########
# Customer ID: 2
# Current time: 0.9340097507304249
# Customer 2 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 0.9340097507304249
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 0.9340097507304249
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 0.9340097507304249
#
# <br />########### Event: 4 ###########
# Customer ID: 2
# Current time: 1.3710834966746772
# Customer 2 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 1.3710834966746772
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.3710834966746772
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.3710834966746772
#
# <br />########### Event: 5 ###########
# Customer ID: 3
# Current time: 2.6797850584908303
# Customer 3 is arriving at server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 2.6797850584908303
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 2.6797850584908303
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 2.6797850584908303
#
# <br />########### Event: 7 ###########
# Customer ID: 4
# Current time: 3.1808036774244095
# Customer 4 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 3.1808036774244095
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 3.1808036774244095
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 3.1808036774244095
#
# <br />########### Event: 9 ###########
# Customer ID: 5
# Current time: 3.5260524841129253
# Customer 5 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 3.5260524841129253
#   Server 1: In Service = 1, Queue Length = 1
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 3.5260524841129253
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 3.5260524841129253
#
# <br />########### Event: 2 ###########
# Customer ID: 1
# Current time: 3.6436943267512025
# Customer 1 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 1
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, Inf)
# Deviation: (4, Inf)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 3.6436943267512025
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 3.6436943267512025
# Average queue length: 0.03228641924614167
# Sorted state times (State -> Time Spent):
#   State 0: 3.5260524841129253
#   State 1: 0.11764184263827726
#
# <br />########### Event: 6 ###########
# Customer ID: 3
# Current time: 3.7600253575093463
# Customer 3 is leaving from server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, Inf)
# Deviation: (4, 0.030938895272557793)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 3.7600253575093463
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 3.7600253575093463
# Average queue length: 0.0312875131023594
# Sorted state times (State -> Time Spent):
#   State 0: 3.642383514871069
#   State 1: 0.11764184263827726
#
# <br />########### Event: 11 ###########
# Customer ID: 6
# Current time: 3.7601018131822306
# Customer 6 is arriving at server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, 0.03095859958443796)
# Deviation: (4, 2.033340496697227e-5)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 3.7601018131822306
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 3.7601018131822306
# Average queue length: 0.03128687692068508
# Sorted state times (State -> Time Spent):
#   State 0: 3.6424599705439533
#   State 1: 0.11764184263827726
#
# <br />########### Event: 10 ###########
# Customer ID: 5
# Current time: 4.591030620033775
# Customer 5 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, 0.20634501742347414)
# Deviation: (3, 0.18100625574096385)
# Deviation: (4, 0.18098960247087872)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 4.591030620033775
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 4.591030620033775
# Average queue length: 0.02562427750425498
# Sorted state times (State -> Time Spent):
#   State 0: 4.473388777395498
#   State 1: 0.11764184263827726
#
# <br />########### Event: 12 ###########
# Customer ID: 6
# Current time: 4.902255855645436
# Customer 6 is leaving from server 3.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.256731098081075)
# Deviation: (2, 0.2330009962292558)
# Deviation: (3, 0.2329854002107827)
# Deviation: (4, 0.06348612654585402)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 4.902255855645436
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 4.902255855645436
# Average queue length: 0.023997491379973767
# Sorted state times (State -> Time Spent):
#   State 0: 4.784614013007158
#   State 1: 0.11764184263827726
#
# <br />########### Event: 13 ###########
# Customer ID: 7
# Current time: 5.187453227543873
# Customer 7 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.27516929935007395)
# Deviation: (2, 0.2751545607742197)
# Deviation: (3, 0.1149740694225958)
# Deviation: (4, 0.05497830233612953)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 5.187453227543873
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 5.187453227543873
# Average queue length: 0.022678150043576907
# Sorted state times (State -> Time Spent):
#   State 0: 5.069811384905596
#   State 1: 0.11764184263827726
#
# <br />########### Event: 8 ###########
# Customer ID: 4
# Current time: 5.676069547455073
# Customer 4 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.3375518425654047)
# Deviation: (2, 0.19116025946295653)
# Deviation: (3, 0.13632914208328997)
# Deviation: (4, 0.08608356818500867)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 5.676069547455073
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 5.676069547455073
# Average queue length: 0.020725933967990797
# Sorted state times (State -> Time Spent):
#   State 0: 5.558427704816796
#   State 1: 0.11764184263827726
#
# <br />########### Event: 14 ###########
# Customer ID: 7
# Current time: 5.874196193942615
# Customer 7 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.21844104819515922)
# Deviation: (2, 0.1654592911451324)
# Deviation: (3, 0.11690841499419122)
# Deviation: (4, 0.03372829914871535)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 5.874196193942615
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 5.874196193942615
# Average queue length: 0.020026883466981883
# Sorted state times (State -> Time Spent):
#   State 0: 5.756554351304338
#   State 1: 0.11764184263827726
#
# <br />########### Event: 15 ###########
# Customer ID: 8
# Current time: 6.3718880268929
# Customer 8 is arriving at server 3.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.23064312571796644)
# Deviation: (2, 0.18588443399351257)
# Deviation: (3, 0.10920130367970787)
# Deviation: (4, 0.07810743548062192)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 6.3718880268929
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 6.3718880268929
# Average queue length: 0.01846263495870666
# Sorted state times (State -> Time Spent):
#   State 0: 6.254246184254622
#   State 1: 0.11764184263827726
#
# <br />########### Event: 17 ###########
# Customer ID: 9
# Current time: 7.582015802934658
# Customer 9 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.315821364347982)
# Deviation: (2, 0.25137724650242455)
# Deviation: (3, 0.22524611572703687)
# Deviation: (4, 0.159605018967828)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 7.582015802934658
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 7.582015802934658
# Average queue length: 0.0155159057559262
# Sorted state times (State -> Time Spent):
#   State 0: 7.46437396029638
#   State 1: 0.11764184263827726
#
# <br />########### Event: 19 ###########
# Customer ID: 10
# Current time: 7.667613080725319
# Customer 10 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.25973448481334366)
# Deviation: (2, 0.23389506850455935)
# Deviation: (3, 0.1689867550945659)
# Deviation: (4, 0.011163484240726017)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 7.667613080725319
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 7.667613080725319
# Average queue length: 0.015342694186539328
# Sorted state times (State -> Time Spent):
#   State 0: 7.549971238087042
#   State 1: 0.11764184263827726
#
# <br />########### Event: 16 ###########
# Customer ID: 8
# Current time: 7.7858432841631515
# Customer 8 is leaving from server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.24552858572287672)
# Deviation: (2, 0.1816059231690827)
# Deviation: (3, 0.026179242734449958)
# Deviation: (4, 0.015185279117847051)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 7.7858432841631515
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 7.7858432841631515
# Average queue length: 0.015109711092896959
# Sorted state times (State -> Time Spent):
#   State 0: 7.668201441524874
#   State 1: 0.11764184263827726
#
# <br />########### Event: 18 ###########
# Customer ID: 9
# Current time: 8.528975627524849
# Customer 9 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.2529128578666073)
# Deviation: (2, 0.11102855324549736)
# Deviation: (3, 0.10099249715519493)
# Deviation: (4, 0.08713031620860176)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 8.528975627524849
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 8.528975627524849
# Average queue length: 0.013793197187552229
# Sorted state times (State -> Time Spent):
#   State 0: 8.411333784886573
#   State 1: 0.11764184263827726
#
# <br />########### Event: 21 ###########
# Customer ID: 11
# Current time: 9.499630958773235
# Customer 11 is arriving at server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.20186206855410466)
# Deviation: (2, 0.1928514787572863)
# Deviation: (3, 0.18040571071103997)
# Deviation: (4, 0.1021782146549548)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 9.499630958773235
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 9.499630958773235
# Average queue length: 0.012383832924544399
# Sorted state times (State -> Time Spent):
#   State 0: 9.381989116134958
#   State 1: 0.11764184263827726
#
# <br />########### Event: 22 ###########
# Customer ID: 11
# Current time: 9.957569729495575
# Customer 11 is leaving from server 3.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.22997143991742436)
# Deviation: (2, 0.21809804041838599)
# Deviation: (3, 0.1434681494360064)
# Deviation: (4, 0.04598900968434766)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 9.957569729495575
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 9.957569729495575
# Average queue length: 0.011814312712248183
# Sorted state times (State -> Time Spent):
#   State 0: 9.839927886857298
#   State 1: 0.11764184263827726
#
# <br />########### Event: 20 ###########
# Customer ID: 10
# Current time: 10.580483678546372
# Customer 10 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.2641316294499657)
# Deviation: (2, 0.19389548846252505)
# Deviation: (3, 0.10215532225287008)
# Deviation: (4, 0.0588738632349914)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 10.580483678546372
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 10.580483678546372
# Average queue length: 0.011118758481411863
# Sorted state times (State -> Time Spent):
#   State 0: 10.462841835908096
#   State 1: 0.11764184263827726
#
# <br />########### Event: 23 ###########
# Customer ID: 12
# Current time: 14.387490909815337
# Customer 12 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.4071950640325847)
# Deviation: (2, 0.33972983765414844)
# Deviation: (3, 0.3079008847399244)
# Deviation: (4, 0.2646053613609426)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 14.387490909815337
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 14.387490909815337
# Average queue length: 0.008176675375552831
# Sorted state times (State -> Time Spent):
#   State 0: 14.269849067177061
#   State 1: 0.11764184263827726
#
# <br />########### Event: 24 ###########
# Customer ID: 12
# Current time: 14.738184681478582
# Customer 12 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.3554409064563166)
# Deviation: (2, 0.32436932059826795)
# Deviation: (3, 0.28210401028270304)
# Deviation: (4, 0.023794909566030992)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 14.738184681478582
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 14.738184681478582
# Average queue length: 0.00798211212444076
# Sorted state times (State -> Time Spent):
#   State 0: 14.620542838840306
#   State 1: 0.11764184263827726
#
# <br />########### Event: 25 ###########
# Customer ID: 13
# Current time: 15.850081510117228
# Customer 13 is arriving at server 3.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.37176539293254857)
# Deviation: (2, 0.3324650304294796)
# Deviation: (3, 0.09227653494200072)
# Deviation: (4, 0.07015085871507434)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 15.850081510117228
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 15.850081510117228
# Average queue length: 0.007422160104551234
# Sorted state times (State -> Time Spent):
#   State 0: 15.732439667478952
#   State 1: 0.11764184263827726
#
# <br />########### Event: 27 ###########
# Customer ID: 14
# Current time: 18.246925976808626
# Customer 14 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.4201497999173178)
# Deviation: (2, 0.21151152100351214)
# Deviation: (3, 0.19229218662856215)
# Deviation: (4, 0.13135606894759835)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 18.246925976808626
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 18.246925976808626
# Average queue length: 0.006447214330117688
# Sorted state times (State -> Time Spent):
#   State 0: 18.129284134170348
#   State 1: 0.11764184263827726
#
# <br />########### Event: 29 ###########
# Customer ID: 15
# Current time: 18.76529274476484
# Customer 15 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.23329248813189057)
# Deviation: (2, 0.21460406283348518)
# Deviation: (3, 0.1553512260266177)
# Deviation: (4, 0.027623697376148254)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 18.76529274476484
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 18.76529274476484
# Average queue length: 0.006269118432543351
# Sorted state times (State -> Time Spent):
#   State 0: 18.64765090212656
#   State 1: 0.11764184263827726
#
# <br />########### Event: 30 ###########
# Customer ID: 15
# Current time: 18.94837309994108
# Customer 15 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.2221926070516095)
# Deviation: (2, 0.1635122748260369)
# Deviation: (3, 0.03701885747302677)
# Deviation: (4, 0.009662061972846006)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 18.94837309994108
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 18.94837309994108
# Average queue length: 0.006208545821733006
# Sorted state times (State -> Time Spent):
#   State 0: 18.8307312573028
#   State 1: 0.11764184263827726
#
# <br />########### Event: 28 ###########
# Customer ID: 14
# Current time: 19.189384106917167
# Customer 14 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.17401822685889257)
# Deviation: (2, 0.049113516351408884)
# Deviation: (3, 0.02210031128614785)
# Deviation: (4, 0.012559600956093838)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 19.189384106917167
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.11764184263827726
# Total simulation time: 19.189384106917167
# Average queue length: 0.006130568963694415
# Sorted state times (State -> Time Spent):
#   State 0: 19.07174226427889
#   State 1: 0.11764184263827726
#
# <br />########### Event: 31 ###########
# Customer ID: 16
# Current time: 19.92848057322151
# Customer 16 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
#   Server 3: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.08437946838116898)
# Deviation: (2, 0.05836811412605537)
# Deviation: (3, 0.04918124438435267)
# Deviation: (4, 0.03708744696258924)
# Deviation: (5, 0.0)
# Steady state reached at time: 19.92848057322151
# Total planned simulation time: 59.792498667046374

# %%
########################### SIMULATION: CloakSloth #############################

simulate_queue(
arrival_rate, 
CloakSloth_service_mean, 
num_customers,
CloakSloth_num_servers, 
max_server_capacity, 
max_queue_length,
time_limit,
true,
)
# Out:
# <br />########### Event: 1 ###########
# Customer ID: 1
# Current time: 1.1970031244303838
# Customer 1 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# System state after event:
# Current time: 1.1970031244303838
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.1970031244303838
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.1970031244303838
#
# <br />########### Event: 2 ###########
# Customer ID: 1
# Current time: 1.2628813666293992
# Customer 1 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# System state after event:
# Current time: 1.2628813666293992
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.2628813666293992
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.2628813666293992
#
# <br />########### Event: 3 ###########
# Customer ID: 2
# Current time: 1.461515440330785
# Customer 2 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 1.461515440330785
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.461515440330785
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.461515440330785
#
# <br />########### Event: 4 ###########
# Customer ID: 2
# Current time: 1.6287117127584525
# Customer 2 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 1.6287117127584525
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.6287117127584525
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.6287117127584525
#
# <br />########### Event: 5 ###########
# Customer ID: 3
# Current time: 1.7232963295899997
# Customer 3 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 1.7232963295899997
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.7232963295899997
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.7232963295899997
#
# <br />########### Event: 6 ###########
# Customer ID: 3
# Current time: 1.7830226551505264
# Customer 3 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 1.7830226551505264
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 1.7830226551505264
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 1.7830226551505264
#
# <br />########### Event: 7 ###########
# Customer ID: 4
# Current time: 2.0539924903805145
# Customer 4 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 2.0539924903805145
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 2.0539924903805145
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 2.0539924903805145
#
# <br />########### Event: 8 ###########
# Customer ID: 4
# Current time: 2.677750706539813
# Customer 4 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 2.677750706539813
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 2.677750706539813
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 2.677750706539813
#
# <br />########### Event: 9 ###########
# Customer ID: 5
# Current time: 4.084060356092431
# Customer 5 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 4.084060356092431
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 4.084060356092431
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 4.084060356092431
#
# <br />########### Event: 11 ###########
# Customer ID: 6
# Current time: 5.432709493893453
# Customer 6 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 5.432709493893453
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 5.432709493893453
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 5.432709493893453
#
# <br />########### Event: 12 ###########
# Customer ID: 6
# Current time: 5.437731106971274
# Customer 6 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 5.437731106971274
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 5.437731106971274
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 5.437731106971274
#
# <br />########### Event: 13 ###########
# Customer ID: 7
# Current time: 6.201135803340143
# Customer 7 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 6.201135803340143
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 6.201135803340143
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 6.201135803340143
#
# <br />########### Event: 10 ###########
# Customer ID: 5
# Current time: 6.943166042265396
# Customer 5 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 6.943166042265396
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 6.943166042265396
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 6.943166042265396
#
# <br />########### Event: 15 ###########
# Customer ID: 8
# Current time: 7.795423580722916
# Customer 8 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 7.795423580722916
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 7.795423580722916
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 7.795423580722916
#
# <br />########### Event: 16 ###########
# Customer ID: 8
# Current time: 8.248556620565886
# Customer 8 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 8.248556620565886
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 8.248556620565886
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 8.248556620565886
#
# <br />########### Event: 17 ###########
# Customer ID: 9
# Current time: 8.643233569860048
# Customer 9 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 8.643233569860048
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 8.643233569860048
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 8.643233569860048
#
# <br />########### Event: 14 ###########
# Customer ID: 7
# Current time: 9.026932310713345
# Customer 7 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 9.026932310713345
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 9.026932310713345
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 9.026932310713345
#
# <br />########### Event: 19 ###########
# Customer ID: 10
# Current time: 9.743651597176068
# Customer 10 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 9.743651597176068
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 9.743651597176068
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 9.743651597176068
#
# <br />########### Event: 21 ###########
# Customer ID: 11
# Current time: 9.832733791383475
# Customer 11 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, NaN)
# Deviation: (2, NaN)
# Deviation: (3, NaN)
# Deviation: (4, NaN)
# Deviation: (5, NaN)
# System state after event:
# Current time: 9.832733791383475
#   Server 1: In Service = 1, Queue Length = 1
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.0
# Total simulation time: 9.832733791383475
# Average queue length: 0.0
# Sorted state times (State -> Time Spent):
#   State 0: 9.832733791383475
#
# <br />########### Event: 18 ###########
# Customer ID: 9
# Current time: 10.02515061266818
# Customer 9 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 1
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, Inf)
# Deviation: (4, Inf)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 10.02515061266818
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 10.02515061266818
# Average queue length: 0.01919340952758938
# Sorted state times (State -> Time Spent):
#   State 0: 9.832733791383475
#   State 1: 0.19241682128470394
#
# <br />########### Event: 22 ###########
# Customer ID: 11
# Current time: 10.232945119371061
# Customer 11 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, Inf)
# Deviation: (4, 0.02030642246966865)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 10.232945119371061
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 10.232945119371061
# Average queue length: 0.018803660045088787
# Sorted state times (State -> Time Spent):
#   State 0: 10.040528298086357
#   State 1: 0.19241682128470394
#
# <br />########### Event: 23 ###########
# Customer ID: 12
# Current time: 10.982388750012664
# Customer 12 is arriving at server 1.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, Inf)
# Deviation: (3, 0.08716119590497837)
# Deviation: (4, 0.06824049373054085)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 10.982388750012664
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 10.982388750012664
# Average queue length: 0.017520488999670684
# Sorted state times (State -> Time Spent):
#   State 0: 10.78997192872796
#   State 1: 0.19241682128470394
#
# <br />########### Event: 20 ###########
# Customer ID: 10
# Current time: 11.416873035837925
# Customer 10 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, Inf)
# Deviation: (2, 0.12190049051093807)
# Deviation: (3, 0.10369984081897697)
# Deviation: (4, 0.03805632982528593)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 11.416873035837925
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 11.416873035837925
# Average queue length: 0.016853723491598922
# Sorted state times (State -> Time Spent):
#   State 0: 11.224456214553221
#   State 1: 0.19241682128470394
#
# <br />########### Event: 24 ###########
# Customer ID: 12
# Current time: 11.446057788263492
# Customer 12 is leaving from server 1.
# System state before event:
#   Server 1: In Service = 1, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.12413943751465911)
# Deviation: (2, 0.10598519519413281)
# Deviation: (3, 0.04050905969793929)
# Deviation: (4, 0.0025497645534773203)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 11.446057788263492
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 11.446057788263492
# Average queue length: 0.016810750464845935
# Sorted state times (State -> Time Spent):
#   State 0: 11.253640966978788
#   State 1: 0.19241682128470394
#
# <br />########### Event: 25 ###########
# Customer ID: 13
# Current time: 11.55692639441651
# Customer 13 is arriving at server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 0, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.11456171215948072)
# Deviation: (2, 0.049713706291443026)
# Deviation: (3, 0.01211856455590566)
# Deviation: (4, 0.009593260558151788)
# Deviation: (5, 0.0)
# System state after event:
# Current time: 11.55692639441651
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers: 0
# Total waiting time in queue: 0.19241682128470394
# Total simulation time: 11.55692639441651
# Average queue length: 0.016649480555458597
# Sorted state times (State -> Time Spent):
#   State 0: 11.364509573131807
#   State 1: 0.19241682128470394
#
# <br />########### Event: 26 ###########
# Customer ID: 13
# Current time: 11.704349507960151
# Customer 13 is leaving from server 2.
# System state before event:
#   Server 1: In Service = 0, Queue Length = 0
#   Server 2: In Service = 1, Queue Length = 0
# Total lost customers so far: 0
# <br />Deviations:
# Deviation: (1, 0.06168311681537539)
# Deviation: (2, 0.024561507833195904)
# Deviation: (3, 0.022068011513240775)
# Deviation: (4, 0.012595583671128122)
# Deviation: (5, 0.0)
# Steady state reached at time: 11.704349507960151
# Total planned simulation time: 56.008256123753675

# %% [markdown]
# # Solving the tasks
#
# ## The statistics:
#
# ### 1. CloakFloat
#
# Total waiting time in queue: 3.997855249056949
#
# Total simulation time: 7.408373443192805
#
# Average queue length: 0.5396400815526361
#
# System state before event:
#
#   Server 1: In Service = 1, Queue Length = 0
#
#   Server 2: In Service = 1, Queue Length = 0
#
#   Server 3: In Service = 1, Queue Length = 0
#
# Steady state reached at time: 7.626831134748431
#
# ### 2. CloakSloth
#
# Total waiting time in queue: 1.7133937228962726
#
# Total simulation time: 10.320377180900767
#
# Average queue length: 0.1660204557317087
#
#
# System state before event:
#
#   Server 1: In Service = 1, Queue Length = 0
#
#   Server 2: In Service = 1, Queue Length = 0
#
# Steady state reached at time: 10.974251600487444

# %% [markdown]
# ## Oppgave a:
#
# Steady state condition is set to reach a 0.10 deviation in avg queue length in the last 5 events happening in the system. I used hm5 as inspiration for setting up a steady state condition instead of calulcating with littles formulas.
#
# The steady state conditon is reached in 10.32 for the CloakSloth and 7.49 for the CloakFloat.
#
# When we multiply the simulation time which is the total time in the system, with the arrival rate we get the total number of customers within our system.
#
# L_ClothSloth = λ⋅W = 0.8333⋅10.32 ≈ 8.59 customers
#
# L_CloakFloat = λ⋅W = 0.8333⋅7.49 ≈ 6.24 customers
#
# The CloakFloat has a average queue length on 0.54 customers and the average number of customers in the system is 6.24.
#
# The average queue length is lower for the CloakSloth, which is 0.16 customers and the average number of customers is 7.49.

# %% [markdown]
# ## Oppgave b:
#
# For CloakFloat (3 employees):
#
# Total operations per hour = 50 (arrival rate)
#
# Total cost per hour = 50 * €23.50 = €1175
#
# Total cost before reaching steady state = 6.24 * €23.50 = €146.64
#
#
# For ClothesSloth (2 employees):
#
# Total operations per hour = 50 (arrival rate)
#
# Total cost per hour = 7.49 * €20.90 = €1045
#
# Total cost before reaching steady state = 50 * €20.90 = €156.54
#
# CloakSloth has the lowest waiting time in the system but it uses 44% percent longer time to reach a steady state compared with the cloackFloat system. This means that CloakFloat reaches a state where it maximizes the utilization rate before the CloakSloth system. The CloakFloat is less expensive too looking at the total cost when it has reached a steady state. Given that the total time the system runs is lower and that it reaches a steady state where the deviation of the last 5 events is less than 10 percent, i would recommend CloakFloat.
